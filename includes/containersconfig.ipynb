# %%
# creating path variables for all the required containers
raw_folder_path = 'abfss://raw@formula1projectdb.dfs.core.windows.net'
silver_folder_path  = 'abfss://silver@formula1projectdb.dfs.core.windows.net'
gold_folder_path = 'abfss://gold@formula1projectdb.dfs.core.windows.net'
